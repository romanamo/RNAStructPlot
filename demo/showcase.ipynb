# %% [markdown]
# # Showcase
#
# A quick introduction to plot types of RNAStructPlot.

# %% [markdown]
# ## Parse Structure
#
# The structure can be created using its rna-sequence and its dotbracket-notation.

# %%
using RNAStructPlot
using CairoMakie

rnastruct = Parse.dotbracketbase(
    "CCGAUAGAGGCGUGCGGUCAAGGUCCGG", 
    "(((((...(((.....)))...)).)))"
)
# Out:
# RNAStructPlot.Parse.RNABaseGraph(Graphs.SimpleGraphs.SimpleGraph{Int64}(35, [[2, 28], [1, 3, 27], [2, 4, 26], [3, 5, 24], [4, 6, 23], [5, 7], [6, 8], [7, 9], [8, 10, 19], [9, 11, 18]  …  [9, 18, 20], [19, 21], [20, 22], [21, 23], [5, 22, 24], [4, 23, 25], [24, 26], [3, 25, 27], [2, 26, 28], [1, 27]]), Dict{Any, Char}(5 => 'U', 16 => 'G', 20 => 'A', 12 => 'G', 24 => 'U', 28 => 'G', 8 => 'A', 17 => 'G', 1 => 'C', 19 => 'C'…), Dict{Any, Any}(5 => 23, 4 => 24, 11 => 17, 10 => 18, 2 => 27, 9 => 19, 3 => 26, 1 => 28), RNAStructPlot.Parse.RNATreeGraph(Graphs.SimpleGraphs.SimpleGraph{Int64}(3, [[2], [1, 3], [2, 4], [3]]), Dict{Tuple{Any, Any}, Vector{Tuple{Any, Any}}}((1, 2) => [(1, 28), (2, 27), (3, 26)], (3, 4) => [(9, 19), (10, 18), (11, 17)], (2, 3) => [(4, 24), (5, 23)]), Dict{Any, Vector{Any}}(4 => [11, 17, 12, 13, 14, 15, 16], 2 => [3, 26, 4, 24, 25], 3 => [5, 23, 6, 7, 8, 9, 19, 20, 21, 22], 1 => [1, 28])))

# %% [markdown]
# ## Circle Plot
#
# with bonds as straight lines

# %%
f = Figure()
ax = Axis(f[1,1], title="Circle Plot (straight lines)")

Recipes.circleplot!(f[1,1], rnastruct)

hidedecorations!(ax)
hidespines!(ax)

f

# %% [markdown]
# with bonds as curves

# %%
f = Figure()
ax = Axis(f[1,1], title="Circle Plot (curved lines)")

Recipes.circleplot!(f[1,1], rnastruct, layout=:curves)

hidedecorations!(ax)
hidespines!(ax)

f

# %% [markdown]
# ## Arc Plot

# %%
f = Figure()
ax = Axis(f[1,1], title="Arc Plot")

Recipes.arcplot!(f[1,1], rnastruct)

hidedecorations!(ax)
hidespines!(ax)

f

# %% [markdown]
# ## Structure Plots

# %% [markdown]
# The RNA can be drawn with loops as regular polygons and rectangles as stem regions:

# %%
f = Figure()
ax = Axis(f[1,1], title="Polygonal Struct Plot", aspect=DataAspect())

Recipes.structureplot!(f[1,1], rnastruct, layout=:polygonal)

hidedecorations!(ax)
hidespines!(ax)

f

# %% [markdown]
# Using the polygon methode can come with problems. Sometimes the resulting drawing contains crossing/overlaps. The modified version provides a fallback, which guarantees a drawing without crossing/overlaps.

# %%
f = Figure()
ax = Axis(f[1,1], title="Polygonal Struct Plot", aspect=DataAspect())

Recipes.structureplot!(f[1,1], rnastruct, layout=:modified)

hidedecorations!(ax)
hidespines!(ax)

f
